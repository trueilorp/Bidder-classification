# %% [markdown]
# Credit score classification

# %%
import pandas as pd
dataset = pd.read_csv("credit_score_train.csv")
# Out:
# C:\Users\Simone\AppData\Local\Temp\ipykernel_18348\2907862572.py:2: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv("credit_score_train.csv")

# %%
print("DESCRIPTION OF FEATURES: " + str(dataset.keys()))
print("SHAPE: " + str(dataset.shape))
print("TOTAL NULL: " + str(dataset.isnull().sum()))

import seaborn as sns
sns.heatmap(dataset.isnull(), cbar=False, cmap='viridis')

dataset.hist(bins=20, figsize=(10, 8))
# Out:
# DESCRIPTION OF FEATURES: Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')
# SHAPE: (100000, 28)
# TOTAL NULL: ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9985
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       15002
# ...
