# %% [markdown]
# ### Dataset
#
# - Exploring mental health data (Depression), dataset generated from a deep learning model trained an another real dataset obtained from a survey. 140700 rows × 20 columns. Kaggle competition.
# - Fake and real news dataset. 1 for real, 1 for fake. 50k samples for 4 features. Text pre-processing.
# - Microsoft malware prediction (it's huge, probably too much). 8M samples, more than 80 feature.
# - Enron data, mail fraud phishing. 32 feature. 447417 rows.
# - Facebook Recruiting IV: Human or Robot?

# %% [markdown]
# ### Enron dataset

# %%
import pandas as pd

df = pd.read_csv("data/enron_data_fraud_labeled.csv")
df.head(5)
# Out:
# C:\Users\rikyf\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (7,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   Folder-User Folder-Name                                     Message-ID  \
# 0     maildir    arnold-j  <17334447.1075857585446.JavaMail.evans@thyme>
# 1     maildir    arnold-j  <19171686.1075857585034.JavaMail.evans@thyme>
# 2     maildir    arnold-j  <29887033.1075857630725.JavaMail.evans@thyme>
# 3     maildir    arnold-j   <2526360.1075857584903.JavaMail.evans@thyme>
# 4     maildir    arnold-j  <30102065.1075857630952.JavaMail.evans@thyme>
#
#                                     Date                     From  \
# 0  Thu, 16 Nov 2000 09:30:00 -0800 (PST)          msagel@home.com
# 1   Fri, 8 Dec 2000 05:05:00 -0800 (PST)  slafontaine@globalp.com
# 2  Tue, 15 May 2001 09:43:00 -0700 (PDT)  iceoperations@intcx.com
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447417 entries, 0 to 447416
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Folder-User                447417 non-null  object
#  1   Folder-Name                447417 non-null  object
#  2   Message-ID                 447417 non-null  object
#  3   Date                       447417 non-null  object
#  4   From                       447417 non-null  object
#  5   To                         447417 non-null  object
#  6   Subject                    429397 non-null  object
#  7   Mime-Version               447417 non-null  object
#  8   Content-Type               447417 non-null  object
#  9   Content-Transfer-Encoding  447417 non-null  object
#  10  X-From                     447417 non-null  object
#  11  X-To                       439238 non-null  object
#  12  X-cc                       109637 non-null  object
# ...

# %% [markdown]
# ### Mental health dataset

# %%
df = pd.read_csv("data/playground-series-s4e11/train.csv")
df
# Out:
#             id      Name  Gender   Age           City  \
# 0            0  Aaradhya  Female  49.0       Ludhiana
# 1            1     Vivan    Male  26.0       Varanasi
# 2            2    Yuvraj    Male  33.0  Visakhapatnam
# 3            3    Yuvraj    Male  22.0         Mumbai
# 4            4      Rhea  Female  30.0         Kanpur
# ...        ...       ...     ...   ...            ...
# 140695  140695     Vidya  Female  18.0      Ahmedabad
# 140696  140696      Lata  Female  41.0      Hyderabad
# 140697  140697   Aanchal  Female  24.0        Kolkata
# 140698  140698    Prachi  Female  49.0       Srinagar
# 140699  140699       Sai    Male  27.0          Patna
#
#        Working Professional or Student         Profession  Academic Pressure  \
# 0                 Working Professional               Chef                NaN
# 1                 Working Professional            Teacher                NaN
# 2                              Student                NaN                5.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140700 entries, 0 to 140699
# Data columns (total 20 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   id                                     140700 non-null  int64
#  1   Name                                   140700 non-null  object
#  2   Gender                                 140700 non-null  object
#  3   Age                                    140700 non-null  float64
#  4   City                                   140700 non-null  object
#  5   Working Professional or Student        140700 non-null  object
#  6   Profession                             104070 non-null  object
#  7   Academic Pressure                      27897 non-null   float64
#  8   Work Pressure                          112782 non-null  float64
#  9   CGPA                                   27898 non-null   float64
# ...

# %% [markdown]
# #### Exploring features with missing values

# %%
miss_values_col = []
for feature in df.columns:
    if df[feature].isnull().values.any():
        miss_values_col.append(feature)
miss_values_col
# Out:
# ['Profession',
#  'Academic Pressure',
#  'Work Pressure',
#  'CGPA',
#  'Study Satisfaction',
#  'Job Satisfaction',
#  'Dietary Habits',
#  'Degree',
#  'Financial Stress']

# %% [markdown]
# #### Imbalanced dataset

# %%
df['Depression'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['Depression'].value_counts()[1]/df['Depression'].value_counts()[0]
# Out:
# 0.22206491622731972

# %% [markdown]
# ### Facebook Recruiting IV: Human or Robot?

# %%
bids = pd.read_csv('Data/facebook/bids.csv')

# %%
bids
# Out:
#           bid_id                              bidder_id auction  \
# 0              0  8dac2b259fd1c6d1120e519fb1ac14fbqvax8   ewmzr
# 1              1  668d393e858e8126275433046bbd35c6tywop   aeqok
# 2              2  aa5f360084278b35d746fa6af3a7a1a5ra3xe   wa00e
# 3              3  3939ac3ef7d472a59a9c5f893dd3e39fh9ofi   jefix
# 4              4  8393c48eaf4b8fa96886edc7cf27b372dsibi   jefix
# ...          ...                                    ...     ...
# 7656329  7656329  626159dd6f2228ede002d9f9340f75b7puk8d   3e64w
# 7656330  7656330  a318ea333ceee1ba39a494476386136a826dv   xn0y0
# 7656331  7656331  f5b2bbad20d1d7ded3ed960393bec0f40u6hn   gja6c
# 7656332  7656332  d4bd412590f5106b9d887a43c51b254eldo4f   hmwk8
# 7656333  7656333  0ea62aaa9c3ffcc6db584cb69c1f6c4bcripp   c9ox9
#
#             merchandise    device              time country              ip  \
# 0               jewelry    phone0  9759243157894736      us   69.166.231.58
# ...

# %%
train = pd.read_csv('Data/facebook/train.csv')
train
# Out:
#                                   bidder_id  \
# 0     91a3c57b13234af24875c56fb7e2b2f4rb56a
# 1     624f258b49e77713fc34034560f93fb3hu3jo
# 2     1c5f4fc669099bfbfac515cd26997bd12ruaj
# 3     4bee9aba2abda51bf43d639013d6efe12iycd
# 4     4ab12bc61c82ddd9c2d65e60555808acqgos1
# ...                                     ...
# 2008  369515b3af4f8ca582f90271d30b14b6r52aw
# 2009  f939c17ffc7c39ac9b35b69e5e75179fv9pe2
# 2010  c806dbb2decba0ed3c4ff5e2e60a74c2wjvbl
# 2011  0381a69b7a061e9ace2798fd48f1f537mgq57
# 2012  84a769adc98498f52debfe57b93a0789556f4
#
#                             payment_account  \
# 0     a3d2de7675556553a5f08e4c88d2c228754av
# 1     a3d2de7675556553a5f08e4c88d2c228v1sga
# 2     a3d2de7675556553a5f08e4c88d2c2280cybl
# 3     51d80e233f7b6a7dfdee484a3c120f3b2ita8
# 4     a3d2de7675556553a5f08e4c88d2c22857ddh
# ...                                     ...
# 2008  a1f85275793c4a782f0a668711f41b927ivc9
# 2009  a3d2de7675556553a5f08e4c88d2c2286s1m2
# ...

# %%
test = pd.read_csv('Data/facebook/test.csv')
test
# Out:
#                                   bidder_id  \
# 0     49bb5a3c944b8fc337981cc7a9ccae41u31d7
# 1     a921612b85a1494456e74c09393ccb65ylp4y
# 2     6b601e72a4d264dab9ace9d7b229b47479v6i
# 3     eaf0ed0afc9689779417274b4791726cn5udi
# 4     cdecd8d02ed8c6037e38042c7745f688mx5sf
# ...                                     ...
# 4695  bef56983ba78b2ee064443ae95972877jfkyd
# 4696  4da45cc915c32d4368ac7e773d92d4affwqrr
# 4697  0d0e6220bf59ab9a0c5b5987fb2c34a9p33f9
# 4698  4981c32c54dde65b79dbc48fd9ab6457caqze
# 4699  7ade70030d559a6c255be2f6feca17acnrqs0
#
#                             payment_account  \
# 0     a3d2de7675556553a5f08e4c88d2c228htx90
# 1     a3d2de7675556553a5f08e4c88d2c228rs17i
# 2     925381cce086b8cc9594eee1c77edf665zjpl
# 3     a3d2de7675556553a5f08e4c88d2c228nclv5
# 4     a3d2de7675556553a5f08e4c88d2c228dtdkd
# ...                                     ...
# 4695  0f235a6dfea5a5885d63968826b748b4q4dra
# 4696  9e0adf7481c422654d4d0a849e0e50abiumen
# ...
